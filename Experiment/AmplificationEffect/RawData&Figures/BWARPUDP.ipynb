# %%
import matplotlib.pyplot as plt
from matplotlib.patches import FancyArrow
from matplotlib.patches import Circle
import matplotlib.transforms as transforms

myblue1 = '#74b9ff'
myblue2 = '#546de5'
myred1 = '#ff7675'
myred2 = '#e53528'
mygreen1 = '#00b894'
mygreen2 = '#00cec9'
mygray1 = '#636e72'
mypink1 = '#fab1a0'
mypink2 = '#ff6f91'
mypurple1 = '#a29bfe'
mypurple2 = '#786fa6'
myyellow1 = '#fdcb6e'
myyellow2 = '#f37252'
myyellow3 = '#fdbc63'

btasia = [9.68, 9.69, 9.65, 9.64, 9.7]
nettrail = [9.06, 8.75, 8.07, 8.43, 8.28]
hecanada = [9.04, 8.71, 8.19, 8.17, 8.19]
sprint = [9.13, 8.75, 8.19, 8.46, 8.23]
x = [100, 200, 300, 400, 500]

font1 = {
    'family':'Times New Roman',
    'weight':'normal',
    'size':28
}
fontsize =32

plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

# Input data; groupwise




#labels = ['100', '200', '300', '400', '500', '1k','2k','3k','4k','5k','6k','7k','8k','9k','10k','11k','12k','13k']
labels = ['100','200','300','400','500']
# Setting the positions sip1_1 width for the bars
#pos = list(range(len(attackwithoutp4)))
width = 0.3 # the width of a bar

# Plotting the bars
fig, ax = plt.subplots(figsize=(10,6))

ax.plot(x, btasia, label='port 1',lw = 3, color = myblue2, marker = 'o', markerfacecolor='none', markersize = 30, markeredgewidth = 2)
ax.plot(x, nettrail, label='port 1',lw = 3, color = '#1f77b4', marker = 'v', markerfacecolor='none', markersize = 30, markeredgewidth = 2)
ax.plot(x, hecanada, label='phase 1',lw = 3, color = myred2, marker = '*', markerfacecolor='none', markersize = 36, markeredgewidth = 2)
ax.plot(x, sprint, label='phase 2',lw = 3, color = myyellow2, marker = 'X', markerfacecolor='none', markersize = 30, markeredgewidth = 2)

# 将圆形添加到坐标轴
#ax.add_patch(circle)

# Setting axis labels and ticks
ax.set_ylabel('BW (Mbps)',fontsize = fontsize)
ax.set_xlabel('Attack Speed (pps)',fontsize = fontsize)
ax.set_xticks([p for p in x[::1]] )
ax.tick_params(labelsize =fontsize )
#ax.set_xticklabels(x)
#plt.xticks(rotation=45, ha="right")
# Setting the x-axis and y-axis limits
plt.xlim([80,520])
plt.ylim([0,12])

# Adding the legend and showing the plot
plt.legend(['BAP','NT','HC','ST'], loc='lower left',fontsize = 26, ncol = 2)
plt.grid()
i = 0

plt.tight_layout()
plt.savefig('BWARPUDP.pdf', format='pdf')

plt.show()
