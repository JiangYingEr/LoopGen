# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
import csv
import numpy as np
import matplotlib.patches as patches

fontsize = 32
length = 400

myblue1 = '#74b9ff'
myblue2 = '#546de5'
myred1 = '#ff7675'
mygreen1 = '#00b894'
mygreen2 = '#00cec9'
mygray1 = '#636e72'
mypink1 = '#fab1a0'
mypink2 = '#ff6f91'
mypurple1 = '#a29bfe'
mypurple2 = '#786fa6'
myyellow1 = '#fdcb6e'

#min, avg, max, dev
Min = [19.66, 43.87, 63.91, 77.92]
labels = ['', '']
# Setting the positions sip1_1 width for the bars
pos = list(range(len(Min)))
width = 0.5 # the width of a bar

# Plotting the bars
fig, ax = plt.subplots(figsize=(8,5))

bar0 = plt.bar(pos, Min, width,
             alpha=1,
             #color=myblue1,
             hatch='/',
             label=labels[0],edgecolor='black')

'''
bar1=plt.bar([p +  1*width for p in pos], Avg, width,
             alpha=1,
             color=myblue1,
             hatch='.|', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar2=plt.bar([p +  2*width for p in pos], Max, width,
             alpha=1,
             color=mypink2,
             hatch='\\', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar3=plt.bar([p +  3*width for p in pos], Dev, width,
             alpha=1,
             color=mypink1,
             hatch='-', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar4=plt.bar([p +  4*width for p in pos], efofdp, width,
             alpha=1,
             color=myred1,
             hatch='\\', # this one defines the fill pattern
             label=labels[1],edgecolor='black')
'''
# Setting axis labels and ticks
ax.set_ylabel(r'Success Rate (%)',fontsize = fontsize)
ax.set_xlabel('# of compromised hosts',fontsize = fontsize)
ax.set_xticks([p for p in pos] )
ax.tick_params(labelsize =fontsize )
ax.set_xticklabels(['3','4','5', '6'], fontsize=fontsize)
#plt.xticks(rotation=45, ha="right")
# Setting the x-axis and y-axis limits
plt.xlim(min(pos)-width, max(pos)+width)
plt.ylim([0.9, max(Min) * 1.15])
#plt.xticks(rotation=45, ha="right")
#plt.yscale('log')  
# Adding the legend and showing the plot
#plt.legend(['Min', 'Avg', 'Max', 'Dev'], loc='upper left',fontsize = 32, ncol = 1)
plt.grid()

for bar in bar0:
    height = round(bar.get_height(), 2)
    log_height = np.log2(height)  
    print(height)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)
'''
for bar in bar1:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)

for bar in bar2:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)



for bar in bar3:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)
'''
plt.tight_layout()

plt.savefig('Aarnet.pdf', format='pdf')

plt.show()
# Out:
# 19.66
# 43.87
# 63.91
# 77.92

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
import csv
import numpy as np
import matplotlib.patches as patches

fontsize = 32
length = 400

myblue1 = '#74b9ff'
myblue2 = '#546de5'
myred1 = '#ff7675'
mygreen1 = '#00b894'
mygreen2 = '#00cec9'
mygray1 = '#636e72'
mypink1 = '#fab1a0'
mypink2 = '#ff6f91'
mypurple1 = '#a29bfe'
mypurple2 = '#786fa6'
myyellow1 = '#fdcb6e'

#min, avg, max, dev
Min = [6.90, 19.62, 35.48, 51.52]
labels = ['', '']
# Setting the positions sip1_1 width for the bars
pos = list(range(len(Min)))
width = 0.5 # the width of a bar

# Plotting the bars
fig, ax = plt.subplots(figsize=(8,5))

bar0 = plt.bar(pos, Min, width,
             alpha=1,
             #color=myblue1,
             hatch='/',
             label=labels[0],edgecolor='black')

'''
bar1=plt.bar([p +  1*width for p in pos], Avg, width,
             alpha=1,
             color=myblue1,
             hatch='.|', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar2=plt.bar([p +  2*width for p in pos], Max, width,
             alpha=1,
             color=mypink2,
             hatch='\\', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar3=plt.bar([p +  3*width for p in pos], Dev, width,
             alpha=1,
             color=mypink1,
             hatch='-', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar4=plt.bar([p +  4*width for p in pos], efofdp, width,
             alpha=1,
             color=myred1,
             hatch='\\', # this one defines the fill pattern
             label=labels[1],edgecolor='black')
'''
# Setting axis labels and ticks
ax.set_ylabel(r'Success Rate (%)',fontsize = fontsize)
ax.set_xlabel('# of compromised hosts',fontsize = fontsize)
ax.set_xticks([p for p in pos] )
ax.tick_params(labelsize =fontsize )
ax.set_xticklabels(['3','4','5', '6'], fontsize=fontsize)
#plt.xticks(rotation=45, ha="right")
# Setting the x-axis and y-axis limits
plt.xlim(min(pos)-width, max(pos)+width)
plt.ylim([0.9, max(Min) * 1.15])
#plt.xticks(rotation=45, ha="right")
#plt.yscale('log')  
# Adding the legend and showing the plot
#plt.legend(['Min', 'Avg', 'Max', 'Dev'], loc='upper left',fontsize = 32, ncol = 1)
plt.grid()

for bar in bar0:
    height = round(bar.get_height(), 2)
    log_height = np.log2(height)  
    print(height)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)
'''
for bar in bar1:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)

for bar in bar2:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)



for bar in bar3:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)
'''
plt.tight_layout()

plt.savefig('Nextgen.pdf', format='pdf')

plt.show()
# Out:
# 6.9
# 19.62
# 35.48
# 51.52

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
import csv
import numpy as np
import matplotlib.patches as patches

fontsize = 32
length = 400

myblue1 = '#74b9ff'
myblue2 = '#546de5'
myred1 = '#ff7675'
mygreen1 = '#00b894'
mygreen2 = '#00cec9'
mygray1 = '#636e72'
mypink1 = '#fab1a0'
mypink2 = '#ff6f91'
mypurple1 = '#a29bfe'
mypurple2 = '#786fa6'
myyellow1 = '#fdcb6e'

#min, avg, max, dev
Min = [2.61, 8.09, 15.80, 24.83]
labels = ['', '']
# Setting the positions sip1_1 width for the bars
pos = list(range(len(Min)))
width = 0.5 # the width of a bar

# Plotting the bars
fig, ax = plt.subplots(figsize=(8,5))

bar0 = plt.bar(pos, Min, width,
             alpha=1,
             #color=myblue1,
             hatch='/',
             label=labels[0],edgecolor='black')

'''
bar1=plt.bar([p +  1*width for p in pos], Avg, width,
             alpha=1,
             color=myblue1,
             hatch='.|', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar2=plt.bar([p +  2*width for p in pos], Max, width,
             alpha=1,
             color=mypink2,
             hatch='\\', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar3=plt.bar([p +  3*width for p in pos], Dev, width,
             alpha=1,
             color=mypink1,
             hatch='-', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar4=plt.bar([p +  4*width for p in pos], efofdp, width,
             alpha=1,
             color=myred1,
             hatch='\\', # this one defines the fill pattern
             label=labels[1],edgecolor='black')
'''
# Setting axis labels and ticks
ax.set_ylabel(r'Success Rate (%)',fontsize = fontsize)
ax.set_xlabel('# of compromised hosts',fontsize = fontsize)
ax.set_xticks([p for p in pos] )
ax.tick_params(labelsize =fontsize )
ax.set_xticklabels(['3','4','5', '6'], fontsize=fontsize)
#plt.xticks(rotation=45, ha="right")
# Setting the x-axis and y-axis limits
plt.xlim(min(pos)-width, max(pos)+width)
plt.ylim([0.9, max(Min) * 1.15])
#plt.xticks(rotation=45, ha="right")
#plt.yscale('log')  
# Adding the legend and showing the plot
#plt.legend(['Min', 'Avg', 'Max', 'Dev'], loc='upper left',fontsize = 32, ncol = 1)
plt.grid()

for bar in bar0:
    height = round(bar.get_height(), 2)
    log_height = np.log2(height)  
    print(height)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)
'''
for bar in bar1:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)

for bar in bar2:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)



for bar in bar3:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)
'''
plt.tight_layout()

plt.savefig('Garr201012.pdf', format='pdf')

plt.show()
# Out:
# 2.61
# 8.09
# 15.8
# 24.83

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
import csv
import numpy as np
import matplotlib.patches as patches

fontsize = 32
length = 400

myblue1 = '#74b9ff'
myblue2 = '#546de5'
myred1 = '#ff7675'
mygreen1 = '#00b894'
mygreen2 = '#00cec9'
mygray1 = '#636e72'
mypink1 = '#fab1a0'
mypink2 = '#ff6f91'
mypurple1 = '#a29bfe'
mypurple2 = '#786fa6'
myyellow1 = '#fdcb6e'

#min, avg, max, dev
Min = [7.99, 20.97, 35.36, 48.94]
labels = ['', '']
# Setting the positions sip1_1 width for the bars
pos = list(range(len(Min)))
width = 0.5 # the width of a bar

# Plotting the bars
fig, ax = plt.subplots(figsize=(8,5))

bar0 = plt.bar(pos, Min, width,
             alpha=1,
             #color=myblue1,
             hatch='/',
             label=labels[0],edgecolor='black')

'''
bar1=plt.bar([p +  1*width for p in pos], Avg, width,
             alpha=1,
             color=myblue1,
             hatch='.|', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar2=plt.bar([p +  2*width for p in pos], Max, width,
             alpha=1,
             color=mypink2,
             hatch='\\', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar3=plt.bar([p +  3*width for p in pos], Dev, width,
             alpha=1,
             color=mypink1,
             hatch='-', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar4=plt.bar([p +  4*width for p in pos], efofdp, width,
             alpha=1,
             color=myred1,
             hatch='\\', # this one defines the fill pattern
             label=labels[1],edgecolor='black')
'''
# Setting axis labels and ticks
ax.set_ylabel(r'Success Rate (%)',fontsize = fontsize)
ax.set_xlabel('# of compromised hosts',fontsize = fontsize)
ax.set_xticks([p for p in pos] )
ax.tick_params(labelsize =fontsize )
ax.set_xticklabels(['3','4','5', '6'], fontsize=fontsize)
#plt.xticks(rotation=45, ha="right")
# Setting the x-axis and y-axis limits
plt.xlim(min(pos)-width, max(pos)+width)
plt.ylim([0.9, max(Min) * 1.15])
#plt.xticks(rotation=45, ha="right")
#plt.yscale('log')  
# Adding the legend and showing the plot
#plt.legend(['Min', 'Avg', 'Max', 'Dev'], loc='upper left',fontsize = 32, ncol = 1)
plt.grid()

for bar in bar0:
    height = round(bar.get_height(), 2)
    log_height = np.log2(height)  
    print(height)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)
'''
for bar in bar1:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)

for bar in bar2:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)



for bar in bar3:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)
'''
plt.tight_layout()

plt.savefig('Psinet.pdf', format='pdf')

plt.show()
# Out:
# 7.99
# 20.97
# 35.36
# 48.94

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
import csv
import numpy as np
import matplotlib.patches as patches

fontsize = 32
length = 400

myblue1 = '#74b9ff'
myblue2 = '#546de5'
myred1 = '#ff7675'
mygreen1 = '#00b894'
mygreen2 = '#00cec9'
mygray1 = '#636e72'
mypink1 = '#fab1a0'
mypink2 = '#ff6f91'
mypurple1 = '#a29bfe'
mypurple2 = '#786fa6'
myyellow1 = '#fdcb6e'

#min, avg, max, dev
Min = [6.69, 19.03, 34.14, 49.31]
labels = ['', '']
# Setting the positions sip1_1 width for the bars
pos = list(range(len(Min)))
width = 0.5 # the width of a bar

# Plotting the bars
fig, ax = plt.subplots(figsize=(8,5))

bar0 = plt.bar(pos, Min, width,
             alpha=1,
             #color=myblue1,
             hatch='/',
             label=labels[0],edgecolor='black')

'''
bar1=plt.bar([p +  1*width for p in pos], Avg, width,
             alpha=1,
             color=myblue1,
             hatch='.|', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar2=plt.bar([p +  2*width for p in pos], Max, width,
             alpha=1,
             color=mypink2,
             hatch='\\', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar3=plt.bar([p +  3*width for p in pos], Dev, width,
             alpha=1,
             color=mypink1,
             hatch='-', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar4=plt.bar([p +  4*width for p in pos], efofdp, width,
             alpha=1,
             color=myred1,
             hatch='\\', # this one defines the fill pattern
             label=labels[1],edgecolor='black')
'''
# Setting axis labels and ticks
ax.set_ylabel(r'Success Rate (%)',fontsize = fontsize)
ax.set_xlabel('# of compromised hosts',fontsize = fontsize)
ax.set_xticks([p for p in pos] )
ax.tick_params(labelsize =fontsize )
ax.set_xticklabels(['3','4','5', '6'], fontsize=fontsize)
#plt.xticks(rotation=45, ha="right")
# Setting the x-axis and y-axis limits
plt.xlim(min(pos)-width, max(pos)+width)
plt.ylim([0.9, max(Min) * 1.15])
#plt.xticks(rotation=45, ha="right")
#plt.yscale('log')  
# Adding the legend and showing the plot
#plt.legend(['Min', 'Avg', 'Max', 'Dev'], loc='upper left',fontsize = 32, ncol = 1)
plt.grid()

for bar in bar0:
    height = round(bar.get_height(), 2)
    log_height = np.log2(height)  
    print(height)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)
'''
for bar in bar1:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)

for bar in bar2:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)



for bar in bar3:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)
'''
plt.tight_layout()

plt.savefig('LambdaNet.pdf', format='pdf')

plt.show()
# Out:
# 6.69
# 19.03
# 34.14
# 49.31

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
import csv
import numpy as np
import matplotlib.patches as patches

fontsize = 32
length = 400

myblue1 = '#74b9ff'
myblue2 = '#546de5'
myred1 = '#ff7675'
mygreen1 = '#00b894'
mygreen2 = '#00cec9'
mygray1 = '#636e72'
mypink1 = '#fab1a0'
mypink2 = '#ff6f91'
mypurple1 = '#a29bfe'
mypurple2 = '#786fa6'
myyellow1 = '#fdcb6e'

#min, avg, max, dev
Min = [12.90, 33.83, 54.99, 71.91]
labels = ['', '']
# Setting the positions sip1_1 width for the bars
pos = list(range(len(Min)))
width = 0.5 # the width of a bar

# Plotting the bars
fig, ax = plt.subplots(figsize=(8,5))

bar0 = plt.bar(pos, Min, width,
             alpha=1,
             #color=myblue1,
             hatch='/',
             label=labels[0],edgecolor='black')

'''
bar1=plt.bar([p +  1*width for p in pos], Avg, width,
             alpha=1,
             color=myblue1,
             hatch='.|', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar2=plt.bar([p +  2*width for p in pos], Max, width,
             alpha=1,
             color=mypink2,
             hatch='\\', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar3=plt.bar([p +  3*width for p in pos], Dev, width,
             alpha=1,
             color=mypink1,
             hatch='-', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar4=plt.bar([p +  4*width for p in pos], efofdp, width,
             alpha=1,
             color=myred1,
             hatch='\\', # this one defines the fill pattern
             label=labels[1],edgecolor='black')
'''
# Setting axis labels and ticks
ax.set_ylabel(r'Success Rate (%)',fontsize = fontsize)
ax.set_xlabel('# of compromised hosts',fontsize = fontsize)
ax.set_xticks([p for p in pos] )
ax.tick_params(labelsize =fontsize )
ax.set_xticklabels(['3','4','5', '6'], fontsize=fontsize)
#plt.xticks(rotation=45, ha="right")
# Setting the x-axis and y-axis limits
plt.xlim(min(pos)-width, max(pos)+width)
plt.ylim([0.9, max(Min) * 1.15])
#plt.xticks(rotation=45, ha="right")
#plt.yscale('log')  
# Adding the legend and showing the plot
#plt.legend(['Min', 'Avg', 'Max', 'Dev'], loc='upper left',fontsize = 32, ncol = 1)
plt.grid()

for bar in bar0:
    height = round(bar.get_height(), 2)
    log_height = np.log2(height)  
    print(height)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)
'''
for bar in bar1:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)

for bar in bar2:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)



for bar in bar3:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)
'''
plt.tight_layout()

plt.savefig('Arpanet19723.pdf', format='pdf')

plt.show()
# Out:
# 12.9
# 33.83
# 54.99
# 71.91

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
import csv
import numpy as np
import matplotlib.patches as patches

fontsize = 32
length = 400

myblue1 = '#74b9ff'
myblue2 = '#546de5'
myred1 = '#ff7675'
mygreen1 = '#00b894'
mygreen2 = '#00cec9'
mygray1 = '#636e72'
mypink1 = '#fab1a0'
mypink2 = '#ff6f91'
mypurple1 = '#a29bfe'
mypurple2 = '#786fa6'
myyellow1 = '#fdcb6e'

#min, avg, max, dev
Min = [5.07, 15.30, 28.72, 43.02]
labels = ['', '']
# Setting the positions sip1_1 width for the bars
pos = list(range(len(Min)))
width = 0.5 # the width of a bar

# Plotting the bars
fig, ax = plt.subplots(figsize=(8,5))

bar0 = plt.bar(pos, Min, width,
             alpha=1,
             #color=myblue1,
             hatch='/',
             label=labels[0],edgecolor='black')

'''
bar1=plt.bar([p +  1*width for p in pos], Avg, width,
             alpha=1,
             color=myblue1,
             hatch='.|', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar2=plt.bar([p +  2*width for p in pos], Max, width,
             alpha=1,
             color=mypink2,
             hatch='\\', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar3=plt.bar([p +  3*width for p in pos], Dev, width,
             alpha=1,
             color=mypink1,
             hatch='-', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar4=plt.bar([p +  4*width for p in pos], efofdp, width,
             alpha=1,
             color=myred1,
             hatch='\\', # this one defines the fill pattern
             label=labels[1],edgecolor='black')
'''
# Setting axis labels and ticks
ax.set_ylabel(r'Success Rate (%)',fontsize = fontsize)
ax.set_xlabel('# of compromised hosts',fontsize = fontsize)
ax.set_xticks([p for p in pos] )
ax.tick_params(labelsize =fontsize )
ax.set_xticklabels(['3','4','5', '6'], fontsize=fontsize)
#plt.xticks(rotation=45, ha="right")
# Setting the x-axis and y-axis limits
plt.xlim(min(pos)-width, max(pos)+width)
plt.ylim([0.9, max(Min) * 1.15])
#plt.xticks(rotation=45, ha="right")
#plt.yscale('log')  
# Adding the legend and showing the plot
#plt.legend(['Min', 'Avg', 'Max', 'Dev'], loc='upper left',fontsize = 32, ncol = 1)
plt.grid()

for bar in bar0:
    height = round(bar.get_height(), 2)
    log_height = np.log2(height)  
    print(height)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)
'''
for bar in bar1:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)

for bar in bar2:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)



for bar in bar3:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)
'''
plt.tight_layout()

plt.savefig('Switch.pdf', format='pdf')

plt.show()
# Out:
# 5.07
# 15.3
# 28.72
# 43.02

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
import csv
import numpy as np
import matplotlib.patches as patches

fontsize = 32
length = 400

myblue1 = '#74b9ff'
myblue2 = '#546de5'
myred1 = '#ff7675'
mygreen1 = '#00b894'
mygreen2 = '#00cec9'
mygray1 = '#636e72'
mypink1 = '#fab1a0'
mypink2 = '#ff6f91'
mypurple1 = '#a29bfe'
mypurple2 = '#786fa6'
myyellow1 = '#fdcb6e'

#min, avg, max, dev
Min = [7.14, 20.50, 36.68, 52.59]
labels = ['', '']
# Setting the positions sip1_1 width for the bars
pos = list(range(len(Min)))
width = 0.5 # the width of a bar

# Plotting the bars
fig, ax = plt.subplots(figsize=(8,5))

bar0 = plt.bar(pos, Min, width,
             alpha=1,
             #color=myblue1,
             hatch='/',
             label=labels[0],edgecolor='black')

'''
bar1=plt.bar([p +  1*width for p in pos], Avg, width,
             alpha=1,
             color=myblue1,
             hatch='.|', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar2=plt.bar([p +  2*width for p in pos], Max, width,
             alpha=1,
             color=mypink2,
             hatch='\\', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar3=plt.bar([p +  3*width for p in pos], Dev, width,
             alpha=1,
             color=mypink1,
             hatch='-', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar4=plt.bar([p +  4*width for p in pos], efofdp, width,
             alpha=1,
             color=myred1,
             hatch='\\', # this one defines the fill pattern
             label=labels[1],edgecolor='black')
'''
# Setting axis labels and ticks
ax.set_ylabel(r'Success Rate (%)',fontsize = fontsize)
ax.set_xlabel('# of compromised hosts',fontsize = fontsize)
ax.set_xticks([p for p in pos] )
ax.tick_params(labelsize =fontsize )
ax.set_xticklabels(['3','4','5', '6'], fontsize=fontsize)
#plt.xticks(rotation=45, ha="right")
# Setting the x-axis and y-axis limits
plt.xlim(min(pos)-width, max(pos)+width)
plt.ylim([0.9, max(Min) * 1.15])
#plt.xticks(rotation=45, ha="right")
#plt.yscale('log')  
# Adding the legend and showing the plot
#plt.legend(['Min', 'Avg', 'Max', 'Dev'], loc='upper left',fontsize = 32, ncol = 1)
plt.grid()

for bar in bar0:
    height = round(bar.get_height(), 2)
    log_height = np.log2(height)  
    print(height)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)
'''
for bar in bar1:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)

for bar in bar2:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)



for bar in bar3:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)
'''
plt.tight_layout()

plt.savefig('Renater2006.pdf', format='pdf')

plt.show()
# Out:
# 7.14
# 20.5
# 36.68
# 52.59

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
import csv
import numpy as np
import matplotlib.patches as patches

fontsize = 32
length = 400

myblue1 = '#74b9ff'
myblue2 = '#546de5'
myred1 = '#ff7675'
mygreen1 = '#00b894'
mygreen2 = '#00cec9'
mygray1 = '#636e72'
mypink1 = '#fab1a0'
mypink2 = '#ff6f91'
mypurple1 = '#a29bfe'
mypurple2 = '#786fa6'
myyellow1 = '#fdcb6e'

#min, avg, max, dev
Min = [2.91, 8.93, 17.26, 26.86]
labels = ['', '']
# Setting the positions sip1_1 width for the bars
pos = list(range(len(Min)))
width = 0.5 # the width of a bar

# Plotting the bars
fig, ax = plt.subplots(figsize=(8,5))

bar0 = plt.bar(pos, Min, width,
             alpha=1,
             #color=myblue1,
             hatch='/',
             label=labels[0],edgecolor='black')

'''
bar1=plt.bar([p +  1*width for p in pos], Avg, width,
             alpha=1,
             color=myblue1,
             hatch='.|', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar2=plt.bar([p +  2*width for p in pos], Max, width,
             alpha=1,
             color=mypink2,
             hatch='\\', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar3=plt.bar([p +  3*width for p in pos], Dev, width,
             alpha=1,
             color=mypink1,
             hatch='-', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar4=plt.bar([p +  4*width for p in pos], efofdp, width,
             alpha=1,
             color=myred1,
             hatch='\\', # this one defines the fill pattern
             label=labels[1],edgecolor='black')
'''
# Setting axis labels and ticks
ax.set_ylabel(r'Success Rate (%)',fontsize = fontsize)
ax.set_xlabel('# of compromised hosts',fontsize = fontsize)
ax.set_xticks([p for p in pos] )
ax.tick_params(labelsize =fontsize )
ax.set_xticklabels(['3','4','5', '6'], fontsize=fontsize)
#plt.xticks(rotation=45, ha="right")
# Setting the x-axis and y-axis limits
plt.xlim(min(pos)-width, max(pos)+width)
plt.ylim([0.9, max(Min) * 1.15])
#plt.xticks(rotation=45, ha="right")
#plt.yscale('log')  
# Adding the legend and showing the plot
#plt.legend(['Min', 'Avg', 'Max', 'Dev'], loc='upper left',fontsize = 32, ncol = 1)
plt.grid()

for bar in bar0:
    height = round(bar.get_height(), 2)
    log_height = np.log2(height)  
    print(height)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)
'''
for bar in bar1:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)

for bar in bar2:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)



for bar in bar3:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)
'''
plt.tight_layout()

plt.savefig('Garr200912.pdf', format='pdf')

plt.show()
# Out:
# 2.91
# 8.93
# 17.26
# 26.86

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
import csv
import numpy as np
import matplotlib.patches as patches

fontsize = 32
length = 400

myblue1 = '#74b9ff'
myblue2 = '#546de5'
myred1 = '#ff7675'
mygreen1 = '#00b894'
mygreen2 = '#00cec9'
mygray1 = '#636e72'
mypink1 = '#fab1a0'
mypink2 = '#ff6f91'
mypurple1 = '#a29bfe'
mypurple2 = '#786fa6'
myyellow1 = '#fdcb6e'

#min, avg, max, dev
Min = [3.66, 11.14, 21.26, 32.64]
labels = ['', '']
# Setting the positions sip1_1 width for the bars
pos = list(range(len(Min)))
width = 0.5 # the width of a bar

# Plotting the bars
fig, ax = plt.subplots(figsize=(8,5))

bar0 = plt.bar(pos, Min, width,
             alpha=1,
             #color=myblue1,
             hatch='/',
             label=labels[0],edgecolor='black')

'''
bar1=plt.bar([p +  1*width for p in pos], Avg, width,
             alpha=1,
             color=myblue1,
             hatch='.|', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar2=plt.bar([p +  2*width for p in pos], Max, width,
             alpha=1,
             color=mypink2,
             hatch='\\', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar3=plt.bar([p +  3*width for p in pos], Dev, width,
             alpha=1,
             color=mypink1,
             hatch='-', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar4=plt.bar([p +  4*width for p in pos], efofdp, width,
             alpha=1,
             color=myred1,
             hatch='\\', # this one defines the fill pattern
             label=labels[1],edgecolor='black')
'''
# Setting axis labels and ticks
ax.set_ylabel(r'Success Rate (%)',fontsize = fontsize)
ax.set_xlabel('# of compromised hosts',fontsize = fontsize)
ax.set_xticks([p for p in pos] )
ax.tick_params(labelsize =fontsize )
ax.set_xticklabels(['3','4','5', '6'], fontsize=fontsize)
#plt.xticks(rotation=45, ha="right")
# Setting the x-axis and y-axis limits
plt.xlim(min(pos)-width, max(pos)+width)
plt.ylim([0.9, max(Min) * 1.15])
#plt.xticks(rotation=45, ha="right")
#plt.yscale('log')  
# Adding the legend and showing the plot
#plt.legend(['Min', 'Avg', 'Max', 'Dev'], loc='upper left',fontsize = 32, ncol = 1)
plt.grid()

for bar in bar0:
    height = round(bar.get_height(), 2)
    log_height = np.log2(height)  
    print(height)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)
'''
for bar in bar1:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)

for bar in bar2:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)



for bar in bar3:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)
'''
plt.tight_layout()

plt.savefig('Evolink.pdf', format='pdf')

plt.show()
# Out:
# 3.66
# 11.14
# 21.26
# 32.64

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
import csv
import numpy as np
import matplotlib.patches as patches

fontsize = 32
length = 400

myblue1 = '#74b9ff'
myblue2 = '#546de5'
myred1 = '#ff7675'
mygreen1 = '#00b894'
mygreen2 = '#00cec9'
mygray1 = '#636e72'
mypink1 = '#fab1a0'
mypink2 = '#ff6f91'
mypurple1 = '#a29bfe'
mypurple2 = '#786fa6'
myyellow1 = '#fdcb6e'

#min, avg, max, dev
Min = [1.99, 6.31, 12.57, 20.13]
labels = ['', '']
# Setting the positions sip1_1 width for the bars
pos = list(range(len(Min)))
width = 0.5 # the width of a bar

# Plotting the bars
fig, ax = plt.subplots(figsize=(8,5))

bar0 = plt.bar(pos, Min, width,
             alpha=1,
             #color=myblue1,
             hatch='/',
             label=labels[0],edgecolor='black')

'''
bar1=plt.bar([p +  1*width for p in pos], Avg, width,
             alpha=1,
             color=myblue1,
             hatch='.|', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar2=plt.bar([p +  2*width for p in pos], Max, width,
             alpha=1,
             color=mypink2,
             hatch='\\', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar3=plt.bar([p +  3*width for p in pos], Dev, width,
             alpha=1,
             color=mypink1,
             hatch='-', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar4=plt.bar([p +  4*width for p in pos], efofdp, width,
             alpha=1,
             color=myred1,
             hatch='\\', # this one defines the fill pattern
             label=labels[1],edgecolor='black')
'''
# Setting axis labels and ticks
ax.set_ylabel(r'Success Rate (%)',fontsize = fontsize)
ax.set_xlabel('# of compromised hosts',fontsize = fontsize)
ax.set_xticks([p for p in pos] )
ax.tick_params(labelsize =fontsize )
ax.set_xticklabels(['3','4','5', '6'], fontsize=fontsize)
#plt.xticks(rotation=45, ha="right")
# Setting the x-axis and y-axis limits
plt.xlim(min(pos)-width, max(pos)+width)
plt.ylim([0.9, max(Min) * 1.15])
#plt.xticks(rotation=45, ha="right")
#plt.yscale('log')  
# Adding the legend and showing the plot
#plt.legend(['Min', 'Avg', 'Max', 'Dev'], loc='upper left',fontsize = 32, ncol = 1)
plt.grid()

for bar in bar0:
    height = round(bar.get_height(), 2)
    log_height = np.log2(height)  
    print(height)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)
'''
for bar in bar1:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)

for bar in bar2:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)



for bar in bar3:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)
'''
plt.tight_layout()

plt.savefig('Ilan.pdf', format='pdf')

plt.show()
# Out:
# 1.99
# 6.31
# 12.57
# 20.13

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
import csv
import numpy as np
import matplotlib.patches as patches

fontsize = 32
length = 400

myblue1 = '#74b9ff'
myblue2 = '#546de5'
myred1 = '#ff7675'
mygreen1 = '#00b894'
mygreen2 = '#00cec9'
mygray1 = '#636e72'
mypink1 = '#fab1a0'
mypink2 = '#ff6f91'
mypurple1 = '#a29bfe'
mypurple2 = '#786fa6'
myyellow1 = '#fdcb6e'

#min, avg, max, dev
Min = [16.25, 40.00, 61.94, 78.04]
labels = ['', '']
# Setting the positions sip1_1 width for the bars
pos = list(range(len(Min)))
width = 0.5 # the width of a bar

# Plotting the bars
fig, ax = plt.subplots(figsize=(8,5))

bar0 = plt.bar(pos, Min, width,
             alpha=1,
             #color=myblue1,
             hatch='/',
             label=labels[0],edgecolor='black')

'''
bar1=plt.bar([p +  1*width for p in pos], Avg, width,
             alpha=1,
             color=myblue1,
             hatch='.|', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar2=plt.bar([p +  2*width for p in pos], Max, width,
             alpha=1,
             color=mypink2,
             hatch='\\', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar3=plt.bar([p +  3*width for p in pos], Dev, width,
             alpha=1,
             color=mypink1,
             hatch='-', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar4=plt.bar([p +  4*width for p in pos], efofdp, width,
             alpha=1,
             color=myred1,
             hatch='\\', # this one defines the fill pattern
             label=labels[1],edgecolor='black')
'''
# Setting axis labels and ticks
ax.set_ylabel(r'Success Rate (%)',fontsize = fontsize)
ax.set_xlabel('# of compromised hosts',fontsize = fontsize)
ax.set_xticks([p for p in pos] )
ax.tick_params(labelsize =fontsize )
ax.set_xticklabels(['3','4','5', '6'], fontsize=fontsize)
#plt.xticks(rotation=45, ha="right")
# Setting the x-axis and y-axis limits
plt.xlim(min(pos)-width, max(pos)+width)
plt.ylim([0.9, max(Min) * 1.15])
#plt.xticks(rotation=45, ha="right")
#plt.yscale('log')  
# Adding the legend and showing the plot
#plt.legend(['Min', 'Avg', 'Max', 'Dev'], loc='upper left',fontsize = 32, ncol = 1)
plt.grid()

for bar in bar0:
    height = round(bar.get_height(), 2)
    log_height = np.log2(height)  
    print(height)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)
'''
for bar in bar1:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)

for bar in bar2:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)



for bar in bar3:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)
'''
plt.tight_layout()

plt.savefig('Geant2009.pdf', format='pdf')

plt.show()
# Out:
# 16.25
# 40.0
# 61.94
# 78.04

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
import csv
import numpy as np
import matplotlib.patches as patches

fontsize = 32
length = 400

myblue1 = '#74b9ff'
myblue2 = '#546de5'
myred1 = '#ff7675'
mygreen1 = '#00b894'
mygreen2 = '#00cec9'
mygray1 = '#636e72'
mypink1 = '#fab1a0'
mypink2 = '#ff6f91'
mypurple1 = '#a29bfe'
mypurple2 = '#786fa6'
myyellow1 = '#fdcb6e'

#min, avg, max, dev
Min = [23.96, 52.59, 73.92, 86.78]
labels = ['', '']
# Setting the positions sip1_1 width for the bars
pos = list(range(len(Min)))
width = 0.5 # the width of a bar

# Plotting the bars
fig, ax = plt.subplots(figsize=(8,5))

bar0 = plt.bar(pos, Min, width,
             alpha=1,
             #color=myblue1,
             hatch='/',
             label=labels[0],edgecolor='black')

'''
bar1=plt.bar([p +  1*width for p in pos], Avg, width,
             alpha=1,
             color=myblue1,
             hatch='.|', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar2=plt.bar([p +  2*width for p in pos], Max, width,
             alpha=1,
             color=mypink2,
             hatch='\\', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar3=plt.bar([p +  3*width for p in pos], Dev, width,
             alpha=1,
             color=mypink1,
             hatch='-', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar4=plt.bar([p +  4*width for p in pos], efofdp, width,
             alpha=1,
             color=myred1,
             hatch='\\', # this one defines the fill pattern
             label=labels[1],edgecolor='black')
'''
# Setting axis labels and ticks
ax.set_ylabel(r'Success Rate (%)',fontsize = fontsize)
ax.set_xlabel('# of compromised hosts',fontsize = fontsize)
ax.set_xticks([p for p in pos] )
ax.tick_params(labelsize =fontsize )
ax.set_xticklabels(['3','4','5', '6'], fontsize=fontsize)
#plt.xticks(rotation=45, ha="right")
# Setting the x-axis and y-axis limits
plt.xlim(min(pos)-width, max(pos)+width)
plt.ylim([0.9, max(Min) * 1.15])
#plt.xticks(rotation=45, ha="right")
#plt.yscale('log')  
# Adding the legend and showing the plot
#plt.legend(['Min', 'Avg', 'Max', 'Dev'], loc='upper left',fontsize = 32, ncol = 1)
plt.grid()

for bar in bar0:
    height = round(bar.get_height(), 2)
    log_height = np.log2(height)  
    print(height)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)
'''
for bar in bar1:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)

for bar in bar2:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)



for bar in bar3:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)
'''
plt.tight_layout()

plt.savefig('Arpanet19719.pdf', format='pdf')

plt.show()
# Out:
# 23.96
# 52.59
# 73.92
# 86.78

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
import csv
import numpy as np
import matplotlib.patches as patches

fontsize = 32
length = 400

myblue1 = '#74b9ff'
myblue2 = '#546de5'
myred1 = '#ff7675'
mygreen1 = '#00b894'
mygreen2 = '#00cec9'
mygray1 = '#636e72'
mypink1 = '#fab1a0'
mypink2 = '#ff6f91'
mypurple1 = '#a29bfe'
mypurple2 = '#786fa6'
myyellow1 = '#fdcb6e'

#min, avg, max, dev
Min = [3.13, 9.52, 18.21, 28.08]
labels = ['', '']
# Setting the positions sip1_1 width for the bars
pos = list(range(len(Min)))
width = 0.5 # the width of a bar

# Plotting the bars
fig, ax = plt.subplots(figsize=(8,5))

bar0 = plt.bar(pos, Min, width,
             alpha=1,
             #color=myblue1,
             hatch='/',
             label=labels[0],edgecolor='black')

'''
bar1=plt.bar([p +  1*width for p in pos], Avg, width,
             alpha=1,
             color=myblue1,
             hatch='.|', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar2=plt.bar([p +  2*width for p in pos], Max, width,
             alpha=1,
             color=mypink2,
             hatch='\\', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar3=plt.bar([p +  3*width for p in pos], Dev, width,
             alpha=1,
             color=mypink1,
             hatch='-', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar4=plt.bar([p +  4*width for p in pos], efofdp, width,
             alpha=1,
             color=myred1,
             hatch='\\', # this one defines the fill pattern
             label=labels[1],edgecolor='black')
'''
# Setting axis labels and ticks
ax.set_ylabel(r'Success Rate (%)',fontsize = fontsize)
ax.set_xlabel('# of compromised hosts',fontsize = fontsize)
ax.set_xticks([p for p in pos] )
ax.tick_params(labelsize =fontsize )
ax.set_xticklabels(['3','4','5', '6'], fontsize=fontsize)
#plt.xticks(rotation=45, ha="right")
# Setting the x-axis and y-axis limits
plt.xlim(min(pos)-width, max(pos)+width)
plt.ylim([0.9, max(Min) * 1.15])
#plt.xticks(rotation=45, ha="right")
#plt.yscale('log')  
# Adding the legend and showing the plot
#plt.legend(['Min', 'Avg', 'Max', 'Dev'], loc='upper left',fontsize = 32, ncol = 1)
plt.grid()

for bar in bar0:
    height = round(bar.get_height(), 2)
    log_height = np.log2(height)  
    print(height)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)
'''
for bar in bar1:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)

for bar in bar2:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)



for bar in bar3:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)
'''
plt.tight_layout()

plt.savefig('Harnet.pdf', format='pdf')

plt.show()
# Out:
# 3.13
# 9.52
# 18.21
# 28.08

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
import csv
import numpy as np
import matplotlib.patches as patches

fontsize = 32
length = 400

myblue1 = '#74b9ff'
myblue2 = '#546de5'
myred1 = '#ff7675'
mygreen1 = '#00b894'
mygreen2 = '#00cec9'
mygray1 = '#636e72'
mypink1 = '#fab1a0'
mypink2 = '#ff6f91'
mypurple1 = '#a29bfe'
mypurple2 = '#786fa6'
myyellow1 = '#fdcb6e'

#min, avg, max, dev
Min = [2.99, 9.39, 18.47, 29.08]
labels = ['', '']
# Setting the positions sip1_1 width for the bars
pos = list(range(len(Min)))
width = 0.5 # the width of a bar

# Plotting the bars
fig, ax = plt.subplots(figsize=(8,5))

bar0 = plt.bar(pos, Min, width,
             alpha=1,
             #color=myblue1,
             hatch='/',
             label=labels[0],edgecolor='black')

'''
bar1=plt.bar([p +  1*width for p in pos], Avg, width,
             alpha=1,
             color=myblue1,
             hatch='.|', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar2=plt.bar([p +  2*width for p in pos], Max, width,
             alpha=1,
             color=mypink2,
             hatch='\\', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar3=plt.bar([p +  3*width for p in pos], Dev, width,
             alpha=1,
             color=mypink1,
             hatch='-', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar4=plt.bar([p +  4*width for p in pos], efofdp, width,
             alpha=1,
             color=myred1,
             hatch='\\', # this one defines the fill pattern
             label=labels[1],edgecolor='black')
'''
# Setting axis labels and ticks
ax.set_ylabel(r'Success Rate (%)',fontsize = fontsize)
ax.set_xlabel('# of compromised hosts',fontsize = fontsize)
ax.set_xticks([p for p in pos] )
ax.tick_params(labelsize =fontsize )
ax.set_xticklabels(['3','4','5', '6'], fontsize=fontsize)
#plt.xticks(rotation=45, ha="right")
# Setting the x-axis and y-axis limits
plt.xlim(min(pos)-width, max(pos)+width)
plt.ylim([0.9, max(Min) * 1.15])
#plt.xticks(rotation=45, ha="right")
#plt.yscale('log')  
# Adding the legend and showing the plot
#plt.legend(['Min', 'Avg', 'Max', 'Dev'], loc='upper left',fontsize = 32, ncol = 1)
plt.grid()

for bar in bar0:
    height = round(bar.get_height(), 2)
    log_height = np.log2(height)  
    print(height)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)
'''
for bar in bar1:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)

for bar in bar2:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)



for bar in bar3:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)
'''
plt.tight_layout()

plt.savefig('BeyondTheNetwork.pdf', format='pdf')

plt.show()
# Out:
# 2.99
# 9.39
# 18.47
# 29.08

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
import csv
import numpy as np
import matplotlib.patches as patches

fontsize = 32
length = 400

myblue1 = '#74b9ff'
myblue2 = '#546de5'
myred1 = '#ff7675'
mygreen1 = '#00b894'
mygreen2 = '#00cec9'
mygray1 = '#636e72'
mypink1 = '#fab1a0'
mypink2 = '#ff6f91'
mypurple1 = '#a29bfe'
mypurple2 = '#786fa6'
myyellow1 = '#fdcb6e'

#min, avg, max, dev
Min = [31.12, 62.90, 82.74, 92.67]
labels = ['', '']
# Setting the positions sip1_1 width for the bars
pos = list(range(len(Min)))
width = 0.5 # the width of a bar

# Plotting the bars
fig, ax = plt.subplots(figsize=(8,5))

bar0 = plt.bar(pos, Min, width,
             alpha=1,
             #color=myblue1,
             hatch='/',
             label=labels[0],edgecolor='black')

'''
bar1=plt.bar([p +  1*width for p in pos], Avg, width,
             alpha=1,
             color=myblue1,
             hatch='.|', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar2=plt.bar([p +  2*width for p in pos], Max, width,
             alpha=1,
             color=mypink2,
             hatch='\\', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar3=plt.bar([p +  3*width for p in pos], Dev, width,
             alpha=1,
             color=mypink1,
             hatch='-', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar4=plt.bar([p +  4*width for p in pos], efofdp, width,
             alpha=1,
             color=myred1,
             hatch='\\', # this one defines the fill pattern
             label=labels[1],edgecolor='black')
'''
# Setting axis labels and ticks
ax.set_ylabel(r'Success Rate (%)',fontsize = fontsize)
ax.set_xlabel('# of compromised hosts',fontsize = fontsize)
ax.set_xticks([p for p in pos] )
ax.tick_params(labelsize =fontsize )
ax.set_xticklabels(['3','4','5', '6'], fontsize=fontsize)
#plt.xticks(rotation=45, ha="right")
# Setting the x-axis and y-axis limits
plt.xlim(min(pos)-width, max(pos)+width)
plt.ylim([0.9, max(Min) * 1.15])
#plt.xticks(rotation=45, ha="right")
#plt.yscale('log')  
# Adding the legend and showing the plot
#plt.legend(['Min', 'Avg', 'Max', 'Dev'], loc='upper left',fontsize = 32, ncol = 1)
plt.grid()

for bar in bar0:
    height = round(bar.get_height(), 2)
    log_height = np.log2(height)  
    print(height)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)
'''
for bar in bar1:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)

for bar in bar2:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)



for bar in bar3:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)
'''
plt.tight_layout()

plt.savefig('Ibm.pdf', format='pdf')

plt.show()
# Out:
# 31.12
# 62.9
# 82.74
# 92.67

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
import csv
import numpy as np
import matplotlib.patches as patches

fontsize = 32
length = 400

myblue1 = '#74b9ff'
myblue2 = '#546de5'
myred1 = '#ff7675'
mygreen1 = '#00b894'
mygreen2 = '#00cec9'
mygray1 = '#636e72'
mypink1 = '#fab1a0'
mypink2 = '#ff6f91'
mypurple1 = '#a29bfe'
mypurple2 = '#786fa6'
myyellow1 = '#fdcb6e'

#min, avg, max, dev
Min = [66.87, 91.15, 97.84, 99.5]
labels = ['', '']
# Setting the positions sip1_1 width for the bars
pos = list(range(len(Min)))
width = 0.5 # the width of a bar

# Plotting the bars
fig, ax = plt.subplots(figsize=(8,5))

bar0 = plt.bar(pos, Min, width,
             alpha=1,
             color=mypurple1,
             hatch='/',
             label=labels[0],edgecolor='black')

'''
bar1=plt.bar([p +  1*width for p in pos], Avg, width,
             alpha=1,
             color=myblue1,
             hatch='.|', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar2=plt.bar([p +  2*width for p in pos], Max, width,
             alpha=1,
             color=mypink2,
             hatch='\\', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar3=plt.bar([p +  3*width for p in pos], Dev, width,
             alpha=1,
             color=mypink1,
             hatch='-', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar4=plt.bar([p +  4*width for p in pos], efofdp, width,
             alpha=1,
             color=myred1,
             hatch='\\', # this one defines the fill pattern
             label=labels[1],edgecolor='black')
'''
# Setting axis labels and ticks
ax.set_ylabel(r'Success Rate (%)',fontsize = fontsize)
ax.set_xlabel('# of compromised hosts',fontsize = fontsize)
ax.set_xticks([p for p in pos] )
ax.tick_params(labelsize =fontsize )
ax.set_xticklabels(['3','4','5', '6'], fontsize=fontsize)
#plt.xticks(rotation=45, ha="right")
# Setting the x-axis and y-axis limits
plt.xlim(min(pos)-width, max(pos)+width)
plt.ylim([0.9, max(Min) * 1.15])
#plt.xticks(rotation=45, ha="right")
#plt.yscale('log')  
# Adding the legend and showing the plot
#plt.legend(['Min', 'Avg', 'Max', 'Dev'], loc='upper left',fontsize = 32, ncol = 1)
plt.grid()

for bar in bar0:
    height = round(bar.get_height(), 2)
    log_height = np.log2(height)  
    print(height)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)
'''
for bar in bar1:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)

for bar in bar2:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)



for bar in bar3:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)
'''
plt.tight_layout()

plt.savefig('leafspine.pdf', format='pdf')

plt.show()
# Out:
# 66.87
# 91.15
# 97.84
# 99.5

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
import csv
import numpy as np
import matplotlib.patches as patches

fontsize = 32
length = 400

myblue1 = '#74b9ff'
myblue2 = '#546de5'
myred1 = '#ff7675'
mygreen1 = '#00b894'
mygreen2 = '#00cec9'
mygray1 = '#636e72'
mypink1 = '#fab1a0'
mypink2 = '#ff6f91'
mypurple1 = '#a29bfe'
mypurple2 = '#786fa6'
myyellow1 = '#fdcb6e'

#min, avg, max, dev
Min = [88.82,99.27,99.97, 99.99]
labels = ['', '']
# Setting the positions sip1_1 width for the bars
pos = list(range(len(Min)))
width = 0.5 # the width of a bar

# Plotting the bars
fig, ax = plt.subplots(figsize=(8,5))

bar0 = plt.bar(pos, Min, width,
             alpha=1,
             color=myred1,
             hatch='/',
             label=labels[0],edgecolor='black')

'''
bar1=plt.bar([p +  1*width for p in pos], Avg, width,
             alpha=1,
             color=myblue1,
             hatch='.|', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar2=plt.bar([p +  2*width for p in pos], Max, width,
             alpha=1,
             color=mypink2,
             hatch='\\', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar3=plt.bar([p +  3*width for p in pos], Dev, width,
             alpha=1,
             color=mypink1,
             hatch='-', # this one defines the fill pattern
             label=labels[1],edgecolor='black')

bar4=plt.bar([p +  4*width for p in pos], efofdp, width,
             alpha=1,
             color=myred1,
             hatch='\\', # this one defines the fill pattern
             label=labels[1],edgecolor='black')
'''
# Setting axis labels and ticks
ax.set_ylabel(r'Success Rate (%)',fontsize = fontsize)
ax.set_xlabel('# of compromised hosts',fontsize = fontsize)
ax.set_xticks([p for p in pos] )
ax.tick_params(labelsize =fontsize )
ax.set_xticklabels(['3','4','5', '6'], fontsize=fontsize)
#plt.xticks(rotation=45, ha="right")
# Setting the x-axis and y-axis limits
plt.xlim(min(pos)-width, max(pos)+width)
plt.ylim([0.9, max(Min) * 1.15])
#plt.xticks(rotation=45, ha="right")
#plt.yscale('log')  
# Adding the legend and showing the plot
#plt.legend(['Min', 'Avg', 'Max', 'Dev'], loc='upper left',fontsize = 32, ncol = 1)
plt.grid()

for bar in bar0:
    height = round(bar.get_height(), 2)
    log_height = np.log2(height)  
    print(height)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)
'''
for bar in bar1:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)

for bar in bar2:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)



for bar in bar3:
    height = round(bar.get_height(), 2)
    ax.text(bar.get_x() + bar.get_width() / 2, height, f"{height}", 
            ha='center', va='bottom', fontsize=fontsize)
'''
plt.tight_layout()

plt.savefig('fattree.pdf', format='pdf')

plt.show()
# Out:
# 88.82
# 99.27
# 99.97
# 99.99
